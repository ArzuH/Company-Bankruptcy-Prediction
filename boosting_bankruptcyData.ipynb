# %%
import pandas as pd

# %%
data = pd.read_csv(r'D:\Mtrx\data.csv')
data
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# ...

# %%
data.drop_duplicates(inplace= True)
data
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 96 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Bankrupt?                                                 6819 non-null   int64
#  1    ROA(C) before interest and depreciation before interest  6819 non-null   float64
#  2    ROA(A) before interest and % after tax                   6819 non-null   float64
#  3    ROA(B) before interest and depreciation after tax        6819 non-null   float64
#  4    Operating Gross Margin                                   6819 non-null   float64
#  5    Realized Sales Gross Margin                              6819 non-null   float64
#  6    Operating Profit Rate                                    6819 non-null   float64
#  7    Pre-tax net Interest Rate                                6819 non-null   float64
# ...

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
data.columns
# Out:
# Index(['Bankrupt?', ' ROA(C) before interest and depreciation before interest',
#        ' ROA(A) before interest and % after tax',
#        ' ROA(B) before interest and depreciation after tax',
#        ' Operating Gross Margin', ' Realized Sales Gross Margin',
#        ' Operating Profit Rate', ' Pre-tax net Interest Rate',
#        ' After-tax net Interest Rate',
#        ' Non-industry income and expenditure/revenue',
#        ' Continuous interest rate (after tax)', ' Operating Expense Rate',
#        ' Research and development expense rate', ' Cash flow rate',
#        ' Interest-bearing debt interest rate', ' Tax rate (A)',
#        ' Net Value Per Share (B)', ' Net Value Per Share (A)',
#        ' Net Value Per Share (C)', ' Persistent EPS in the Last Four Seasons',
#        ' Cash Flow Per Share', ' Revenue Per Share (Yuan ¥)',
#        ' Operating Profit Per Share (Yuan ¥)',
#        ' Per Share Net profit before tax (Yuan ¥)',
# ...

# %%
data.apply(lambda x: len(x.unique()))
# Out:
# Bankrupt?                                                      2
#  ROA(C) before interest and depreciation before interest    3333
#  ROA(A) before interest and % after tax                     3151
#  ROA(B) before interest and depreciation after tax          3160
#  Operating Gross Margin                                     3781
#                                                             ...
#  Liability to Equity                                        6819
#  Degree of Financial Leverage (DFL)                         6240
#  Interest Coverage Ratio (Interest expense to EBIT)         6240
#  Net Income Flag                                               1
#  Equity to Liability                                        6819
# Length: 96, dtype: int64

# %%
data['Bankrupt?']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 6814    0
# 6815    0
# 6816    0
# 6817    0
# 6818    0
# Name: Bankrupt?, Length: 6819, dtype: int64

# %%
X = data.drop('Bankrupt?', axis=1)
y = data['Bankrupt?']

# %%
X
# Out:
#        ROA(C) before interest and depreciation before interest  \
# 0                                              0.370594
# 1                                              0.464291
# 2                                              0.426071
# 3                                              0.399844
# 4                                              0.465022
# ...                                                 ...
# 6814                                           0.493687
# 6815                                           0.475162
# 6816                                           0.472725
# 6817                                           0.506264
# 6818                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# 2                                    0.499019
# 3                                    0.451265
# 4                                    0.538432
# ...

# %%
y.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
X_train, y_train, X_test, y_test = train_test_split(X, y, test_size = 0.3, stratify =y) # bele error verirdi

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123, stratify =y)

# %% [markdown]
# # Boosting

# %% [markdown]
# ## XGBoost

# %%
import xgboost
from xgboost import XGBClassifier

# %%
xgbt = XGBClassifier(max_depth = 2,
             learning_rate = 0.2,
             objective  = "multi:softmax",
             num_class = 2,
             booster = "gbtree",
             n_estimators = 10,
             random_state = 123)

# %%
xgbt.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=2, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=10, n_jobs=None, num_class=2,
#               num_parallel_tree=None, ...)

# %%
y_pred = xgbt.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, precision_score, f1_score, recall_score

accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)
# Out:
# Accuracy: 0.968475073313783
# Confusion Matrix:
#  [[1317    3]
#  [  40    4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      1320
#            1       0.57      0.09      0.16        44
#
#     accuracy                           0.97      1364
#    macro avg       0.77      0.54      0.57      1364
# weighted avg       0.96      0.97      0.96      1364

# %%
xgbt_l = XGBClassifier(max_depth = 2, 
                    learning_rate = 0.2,
                    objective = "binary:logistic", 
                    num_classes = 2, 
                    booster = "gbtree", 
                    n_estimators = 10, 
                    random_state = 123                     
                    )

# %%
xgbt_l.fit(X_train, y_train)
# Out:
# c:\Users\arzuh\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:160: UserWarning: [14:49:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0cec3277c4d9d0165-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "num_classes" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=2, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
# ...

# %%
xgbt_l.fit(X_train, y_train)
# Out:
# c:\Users\arzuh\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:160: UserWarning: [14:49:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0cec3277c4d9d0165-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "num_classes" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=2, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
# ...

# %%
y_pred = xgbt_l.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)
# Out:
# Accuracy: 0.9706744868035191
# Confusion Matrix:
#  [[1319    1]
#  [  39    5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      1320
#            1       0.83      0.11      0.20        44
#
#     accuracy                           0.97      1364
#    macro avg       0.90      0.56      0.59      1364
# weighted avg       0.97      0.97      0.96      1364

# %% [markdown]
# ## Catboost

# %%
# !pip install catboost
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from catboost import CatBoostClassifier

# %%
catBoost = CatBoostClassifier(iterations=100,
                          learning_rate=1,
                          depth=2)
# Fit model
catBoost.fit(X_train, y_train)
# Get predictions
preds = catBoost.predict(X_test)
# Out:
# 0:	learn: 0.1189562	total: 5.54ms	remaining: 548ms
# 1:	learn: 0.1014589	total: 10ms	remaining: 492ms
# 2:	learn: 0.0923591	total: 15.7ms	remaining: 506ms
# 3:	learn: 0.0889048	total: 19.4ms	remaining: 467ms
# 4:	learn: 0.0849381	total: 23.4ms	remaining: 445ms
# 5:	learn: 0.0820969	total: 28.2ms	remaining: 442ms
# 6:	learn: 0.0811054	total: 33ms	remaining: 438ms
# 7:	learn: 0.0801080	total: 37ms	remaining: 426ms
# 8:	learn: 0.0796310	total: 41.7ms	remaining: 422ms
# 9:	learn: 0.0770700	total: 47.6ms	remaining: 429ms
# 10:	learn: 0.0762138	total: 52.1ms	remaining: 422ms
# 11:	learn: 0.0739344	total: 56ms	remaining: 411ms
# 12:	learn: 0.0715192	total: 59.9ms	remaining: 401ms
# 13:	learn: 0.0699765	total: 65.3ms	remaining: 401ms
# 14:	learn: 0.0686573	total: 68.3ms	remaining: 387ms
# 15:	learn: 0.0672031	total: 71.3ms	remaining: 374ms
# 16:	learn: 0.0663113	total: 74.1ms	remaining: 362ms
# 17:	learn: 0.0650483	total: 79.3ms	remaining: 361ms
# ...

# %%
from sklearn.metrics import accuracy_score

catBoost.score(X_train, y_train)
# Out:
# 0.9957836846929422

# %%
print("Classification Report for CatBoost:""\n",classification_report(y_test, preds))
# Out:
# Classification Report for CatBoost:
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1320
#            1       0.44      0.25      0.32        44
#
#     accuracy                           0.97      1364
#    macro avg       0.71      0.62      0.65      1364
# weighted avg       0.96      0.97      0.96      1364

# %% [markdown]
# ## AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
base_estimator = DecisionTreeClassifier(max_depth=1)
adaboost = AdaBoostClassifier(estimator=base_estimator, n_estimators=50, random_state=42)

# %%
adaboost.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=1),
#                    random_state=42)

# %%
y_pred = adaboost.predict(X_test)
print("Classification Report for AdaBoost:""\n",classification_report(y_test, y_pred))
# Out:
# Classification Report for AdaBoost:
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1320
#            1       0.39      0.20      0.27        44
#
#     accuracy                           0.96      1364
#    macro avg       0.68      0.60      0.63      1364
# weighted avg       0.96      0.96      0.96      1364

# %%
y_pred_train = adaboost.predict(X_train)
print("Classification Report train for AdaBoost:""\n",classification_report(y_train, y_pred_train))
# Out:
# Classification Report train for AdaBoost:
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      5279
#            1       0.66      0.43      0.52       176
#
#     accuracy                           0.97      5455
#    macro avg       0.82      0.71      0.75      5455
# weighted avg       0.97      0.97      0.97      5455

# %% [markdown]
# ## Lightgbm

# %%
# !pip install lightgbm
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
import lightgbm as lgb

# %%
X_train.shape
# Out:
# (5455, 95)

# %%
y.value_counts()
# Out:
# Bankrupt?
# 0    6599
# 1     220
# Name: count, dtype: int64

# %%
params = {
    'objective': 'binary', 
    'metric': 'binary_logloss', 
    'boosting': 'gbdt', 
    'num_leaves': 31, 
    'learning_rate': 0.05, 
    'feature_fraction': 0.9, 
    'bagging_fraction': 0.8,
    'bagging_freq': 5, 
    'verbose': 5,
    #is_unbalance':True,
    'scale_pos_weight': 80,
    'num_iterations': 100
}

# %%
'''
confusion: 
[[1318    2]
 [  36    8]]
Accuracy: 0.9721407624633431
Precision: 0.8
Recall: 0.18181818181818182
F1 Score: 0.2962962962962963

is_unbalanced

confusion: 
[[1305   15]
 [  29   15]]
Accuracy: 0.967741935483871
Precision: 0.5
Recall: 0.3409090909090909
F1 Score: 0.40540540540540543

scale_pos_weight': 0.75 

confusion: 
[[1318    2]
 [  36    8]]
Accuracy: 0.9721407624633431
Precision: 0.8
Recall: 0.18181818181818182
F1 Score: 0.2962962962962963


confusion: 
[[1303   17]
 [  28   16]]
Accuracy: 0.967008797653959
Precision: 0.48484848484848486
Recall: 0.36363636363636365
F1 Score: 0.4155844155844156
# Out:
#   Cell In[235], line 1
#     '''
#     ^
# SyntaxError: incomplete input

# %%
train_data = lgb.Dataset(X_train, label =y_train)
test_data = lgb.Dataset(X_test, label =y_test)

# %%
lgb_model = lgb.train (params, train_data, valid_sets = [test_data])
# Out:
# c:\Users\arzuh\AppData\Local\Programs\Python\Python310\lib\site-packages\lightgbm\engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 176, number of negative: 5279
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.012324
# [LightGBM] [Debug] init for col-wise cost 0.000065 seconds, init for row-wise cost 0.004192 seconds
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006712 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 23713
# [LightGBM] [Info] Number of data points in the train set: 5455, number of used features: 93
# [LightGBM] [Debug] Use subset for bagging
# ...

# %%
X_train.shape
# Out:
# (5455, 95)

# %%
y_pred = lgb_model.predict(X_test)

# %%
print(f'confusion: \n{confusion_matrix(y_test, y_pred.round())}')
print(f"Accuracy: {accuracy_score(y_test, y_pred.round())}")
print(f"Precision: {precision_score(y_test, y_pred.round())}")
print(f"Recall: {recall_score(y_test, y_pred.round())}")
print(f"F1 Score: {f1_score(y_test, y_pred.round())}")
# Out:
# confusion:
# [[1295   25]
#  [  24   20]]
# Accuracy: 0.9640762463343109
# Precision: 0.4444444444444444
# Recall: 0.45454545454545453
# F1 Score: 0.44943820224719094

# %% [markdown]
# # BAGGING

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators = 1000, random_state = None)

rf.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Mtrx\homeworks\boosting_bankruptcyData.ipynb Cell 53 line 5
#       <a href='vscode-notebook-cell:/d%3A/Mtrx/homeworks/boosting_bankruptcyData.ipynb#Y102sZmlsZQ%3D%3D?line=0'>1</a> from sklearn.ensemble import RandomForestClassifier
#       <a href='vscode-notebook-cell:/d%3A/Mtrx/homeworks/boosting_bankruptcyData.ipynb#Y102sZmlsZQ%3D%3D?line=2'>3</a> rf = RandomForestClassifier(n_estimators = 1000, random_state = None)
# ----> <a href='vscode-notebook-cell:/d%3A/Mtrx/homeworks/boosting_bankruptcyData.ipynb#Y102sZmlsZQ%3D%3D?line=4'>5</a> rf.fit(X_train,y_train)
#
# File c:\Users\arzuh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators = 1000, random_state = None)

rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
print("Classification Report for Random Forest:""\n",classification_report(y_test, y_pred))
# Out:
# Classification Report for Random Forest:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      1320
#            1       0.62      0.11      0.19        44
#
#     accuracy                           0.97      1364
#    macro avg       0.80      0.56      0.59      1364
# weighted avg       0.96      0.97      0.96      1364

# %% [markdown]
# # Feature Importance

# %%
import sklearn
import numpy as np
from sklearn.linear_model import LogisticRegression #create an instance and fit the model 

logmodel = LogisticRegression()
logmodel.fit(X_train, y_train)

coefficients = logmodel.coef_[0]
coefficients = logmodel.coef_[0]
feature_importance = pd.DataFrame({'Feature': X.columns, 'Importance': np.abs(coefficients)})
feature_importance = feature_importance.sort_values('Importance', ascending=True)
feature_importance.plot(x='Feature', y='Importance', kind='barh', figsize=(10, 20))
# Out:
# c:\Users\arzuh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# <Axes: ylabel='Feature'>

# %%
top_10_features = feature_importance.tail(10)
top_10_features.values
# Out:
# array([[' Current Ratio', 5.051112838338016e-10],
#        [' Revenue per person', 7.09457514592153e-10],
#        [' Quick Assets/Current Liability', 1.1434455497510354e-09],
#        [' Accounts Receivable Turnover', 1.1793701655122711e-09],
#        [' Allocation rate per person', 2.1058321881928494e-09],
#        [' Net Value Growth Rate', 2.801092605429236e-09],
#        [' Average Collection Days', 2.9100781249419156e-09],
#        [' Fixed Assets to Assets', 3.4561294842944867e-09],
#        [' Revenue Per Share (Yuan ¥)', 4.121071688349162e-09],
#        [' Interest-bearing debt interest rate', 5.780825566145478e-09]],
#       dtype=object)

# %%
X = data[[' Total Asset Growth Rate', ' Revenue per person', ' Quick Assets/Current Liability', ' Revenue Per Share (Yuan ¥)', ' Average Collection Days', ' Allocation rate per person',' Net Value Growth Rate', ' Interest-bearing debt interest rate', ' Fixed Assets to Assets', ' Accounts Receivable Turnover']]
y = data['Bankrupt?']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
rf = RandomForestClassifier(n_estimators = 1000, random_state = None)

rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
print("Classification Report for Random Forest:""\n",classification_report(y_test, y_pred))
# Out:
# Classification Report for Random Forest:
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1327
#            1       0.64      0.19      0.29        37
#
#     accuracy                           0.98      1364
#    macro avg       0.81      0.59      0.64      1364
# weighted avg       0.97      0.98      0.97      1364

# %% [markdown]
# # Resampling

# %%
pip install -U imbalanced-learn
# Out:
# ...
#      ---------------------------------------- 0.0/235.6 kB ? eta -:--:--
#      ----- --------------------------------- 30.7/235.6 kB 1.3 MB/s eta 0:00:01
#      -------- ---------------------------- 51.2/235.6 kB 525.1 kB/s eta 0:00:01
#      -------------- ---------------------- 92.2/235.6 kB 655.4 kB/s eta 0:00:01
#      -------------------------- --------- 174.1/235.6 kB 952.6 kB/s eta 0:00:01
#      -------------------------------------  235.5/235.6 kB 1.1 MB/s eta 0:00:01
#      ------------------------------------ 235.6/235.6 kB 959.1 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter


smote = SMOTE(random_state=42)

X_resampled, y_resampled = smote.fit_resample(X_train, y_train)

#X_resampled, X_test, y_resampled, y_test = train_test_split(X, y, test_size=0.2, random_state=123, stratify=y)

print("Class distribution after SMOTE:", Counter(y_resampled))

# X_resampled and y_resampled for model training
# Out:
# Class distribution after SMOTE: Counter({0: 5279, 1: 5279})

# %%
xgbt_l.fit(X_resampled, y_resampled)
y_pred = xgbt_l.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)
# Out:
# Accuracy: 0.8914956011730205
# Confusion Matrix:
#  [[1181  139]
#  [   9   35]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.89      0.94      1320
#            1       0.20      0.80      0.32        44
#
#     accuracy                           0.89      1364
#    macro avg       0.60      0.85      0.63      1364
# weighted avg       0.97      0.89      0.92      1364
# c:\Users\arzuh\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:160: UserWarning: [14:55:04] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0cec3277c4d9d0165-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "num_classes" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
xgbt.fit(X_resampled, y_resampled)
y_pred = xgbt.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)
# Out:
# Accuracy: 0.8914956011730205
# Confusion Matrix:
#  [[1181  139]
#  [   9   35]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.89      0.94      1320
#            1       0.20      0.80      0.32        44
#
#     accuracy                           0.89      1364
#    macro avg       0.60      0.85      0.63      1364
# weighted avg       0.97      0.89      0.92      1364

# %%
catBoost.fit(X_resampled, y_resampled)

preds = catBoost.predict(X_test)
catBoost.score(X_resampled, y_resampled)
print("Classification Report for AdaBoost:""\n",classification_report(y_test, y_pred))
# Out:
# 0:	learn: 0.3263746	total: 7.78ms	remaining: 770ms
# 1:	learn: 0.3015886	total: 13.4ms	remaining: 656ms
# 2:	learn: 0.2684777	total: 22.6ms	remaining: 729ms
# 3:	learn: 0.2557374	total: 28.7ms	remaining: 688ms
# 4:	learn: 0.2347385	total: 33.4ms	remaining: 634ms
# 5:	learn: 0.2173390	total: 37.2ms	remaining: 584ms
# 6:	learn: 0.2056366	total: 42.1ms	remaining: 559ms
# 7:	learn: 0.1993214	total: 47.3ms	remaining: 544ms
# 8:	learn: 0.1914423	total: 51.5ms	remaining: 521ms
# 9:	learn: 0.1856186	total: 56.2ms	remaining: 506ms
# 10:	learn: 0.1809935	total: 61.9ms	remaining: 501ms
# 11:	learn: 0.1707708	total: 66.9ms	remaining: 490ms
# 12:	learn: 0.1641472	total: 70.8ms	remaining: 474ms
# 13:	learn: 0.1562739	total: 76ms	remaining: 467ms
# 14:	learn: 0.1490385	total: 79.9ms	remaining: 453ms
# 15:	learn: 0.1425598	total: 83.6ms	remaining: 439ms
# 16:	learn: 0.1367234	total: 88ms	remaining: 430ms
# 17:	learn: 0.1334087	total: 93.3ms	remaining: 425ms
# ...

# %%
adaboost.fit(X_resampled, y_resampled )
y_pred = adaboost.predict(X_test)
print("Classification Report for AdaBoost:""\n",classification_report(y_test, y_pred))
# Out:
# Classification Report for AdaBoost:
#                precision    recall  f1-score   support
#
#            0       0.98      0.93      0.96      1320
#            1       0.21      0.55      0.30        44
#
#     accuracy                           0.92      1364
#    macro avg       0.60      0.74      0.63      1364
# weighted avg       0.96      0.92      0.94      1364

# %% [markdown]
# # Lightgbm

# %%
X_resampled.shape
# Out:
# (10558, 95)

# %%
y_resampled.value_counts()
# Out:
# Bankrupt?
# 0    5279
# 1    5279
# Name: count, dtype: int64

# %%
params = {
    'objective': 'binary',
    'metric': 'binary_logloss',
    'boosting': 'gbdt',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 5,
    #'is_unbalance': True,
    'scale_pos_weight': 0.75,
    'num_iterations': 100}
train_data = lgb.Dataset(X_resampled, label=y_resampled)
test_data = lgb.Dataset(X_test, label=y_test)
model = lgb.train(params, train_data, valid_sets=[test_data])
X_resampled.shape
y_pred = model.predict(X_test)
print(f'confusion: \n{confusion_matrix(y_test, y_pred.round())}')
print(f"Accuracy: {accuracy_score(y_test, y_pred.round())}")
print(f"Precision: {precision_score(y_test, y_pred.round())}")
print(f"Recall: {recall_score(y_test, y_pred.round())}")
print(f"F1 Score: {f1_score(y_test, y_pred.round())}")
# Out:
# c:\Users\arzuh\AppData\Local\Programs\Python\Python310\lib\site-packages\lightgbm\engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 5279, number of negative: 5279
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.011280
# [LightGBM] [Debug] init for col-wise cost 0.000013 seconds, init for row-wise cost 0.002979 seconds
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005546 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 23715
# [LightGBM] [Info] Number of data points in the train set: 10558, number of used features: 93
# [LightGBM] [Debug] Use subset for bagging
# ...

# %%
params = {
    'objective': 'binary',
    'metric': 'binary_logloss',
    'boosting': 'gbdt',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 5,
    'is_unbalance': True,
    #'scale_pos_weight': 0.75,
    'num_iterations': 100}
train_data = lgb.Dataset(X_resampled, label=y_resampled)
test_data = lgb.Dataset(X_test, label=y_test)
model = lgb.train(params, train_data, valid_sets=[test_data])
X_resampled.shape
y_pred = model.predict(X_test)
print(f'confusion: \n{confusion_matrix(y_test, y_pred.round())}')
print(f"Accuracy: {accuracy_score(y_test, y_pred.round())}")
print(f"Precision: {precision_score(y_test, y_pred.round())}")
print(f"Recall: {recall_score(y_test, y_pred.round())}")
print(f"F1 Score: {f1_score(y_test, y_pred.round())}")
# Out:
# c:\Users\arzuh\AppData\Local\Programs\Python\Python310\lib\site-packages\lightgbm\engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 5279, number of negative: 5279
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.011280
# [LightGBM] [Debug] init for col-wise cost 0.000017 seconds, init for row-wise cost 0.003362 seconds
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005340 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 23715
# [LightGBM] [Info] Number of data points in the train set: 10558, number of used features: 93
# [LightGBM] [Debug] Use subset for bagging
# ...

# %% [markdown]
# # Hyperparameter Tuning

# %% [markdown]
# ## GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

# %%
lgb_clf = lgb.LGBMClassifier()

param_grid = {
    'num_leaves': [20, 30, 40],
    'learning_rate': [0.01, 0.1, 0.2],
    'n_estimators': [50, 100, 150]
}

grid_search = GridSearchCV(estimator=lgb_clf, param_grid=param_grid, scoring=make_scorer(accuracy_score), cv=3)
y_pred = grid_search.fit(X_resampled, y_resampled)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 3519, number of negative: 3519
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003204 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 23715
# [LightGBM] [Info] Number of data points in the train set: 7038, number of used features: 93
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 3520, number of negative: 3519
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004598 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 23715
# [LightGBM] [Info] Number of data points in the train set: 7039, number of used features: 93
# ...

# %%
print("Best parameters found: ", grid_search.best_params_)
print("Best accuracy found: ", grid_search.best_score_)
# Out:
# Best parameters found:  {'learning_rate': 0.2, 'n_estimators': 150, 'num_leaves': 40}
# Best accuracy found:  0.989202500279866

# %%
params = {
    'num_leaves': 40,
    'learning_rate': 0.2,   
    'n_estimators': 150}
train_data = lgb.Dataset(X_resampled, label=y_resampled)
test_data = lgb.Dataset(X_test, label=y_test)
model = lgb.train(params, train_data, valid_sets=[test_data])
X_resampled.shape
y_pred = model.predict(X_test)
print(f'confusion: \n{confusion_matrix(y_test, y_pred.round())}')
print(f"Accuracy: {accuracy_score(y_test, y_pred.round())}")
print(f"Precision: {precision_score(y_test, y_pred.round())}")
print(f"Recall: {recall_score(y_test, y_pred.round())}")
print(f"F1 Score: {f1_score(y_test, y_pred.round())}")
# Out:
# c:\Users\arzuh\AppData\Local\Programs\Python\Python310\lib\site-packages\lightgbm\engine.py:172: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006146 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 23715
# [LightGBM] [Info] Number of data points in the train set: 10558, number of used features: 93
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.500000
# confusion:
# [[1284   36]
#  [  25   19]]
# Accuracy: 0.9552785923753666
# Precision: 0.34545454545454546
# Recall: 0.4318181818181818
# F1 Score: 0.3838383838383838

# %%
print(f'confusion: \n{confusion_matrix(y_test, y_pred.round())}')
print(f"Accuracy: {accuracy_score(y_test, y_pred.round())}")
print(f"Precision: {precision_score(y_test, y_pred.round())}")
print(f"Recall: {recall_score(y_test, y_pred.round())}")
print(f"F1 Score: {f1_score(y_test, y_pred.round())}")
# Out:
# confusion:
# [[1295   25]
#  [  24   20]]
# Accuracy: 0.9640762463343109
# Precision: 0.4444444444444444
# Recall: 0.45454545454545453
# F1 Score: 0.44943820224719094

# %% [markdown]
# ## Randomized Search

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint as sp_randint

# %%
lgb_clf = lgb.LGBMClassifier()

param_dist = {
    'num_leaves': sp_randint(6, 50),
    'learning_rate': [0.01, 0.1, 0.2, 0.3],
    'n_estimators': sp_randint(50, 200)
}

random_search = RandomizedSearchCV(estimator=lgb_clf, param_distributions=param_dist, n_iter=100, scoring=make_scorer(accuracy_score), cv=3, random_state=42)
y_pred = random_search.fit(X_resampled, y_resampled)

print("Best parameters found: ", random_search.best_params_)
print("Best accuracy found: ", random_search.best_score_)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 3519, number of negative: 3519
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003314 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 23715
# [LightGBM] [Info] Number of data points in the train set: 7038, number of used features: 93
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 3520, number of negative: 3519
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003639 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 23715
# [LightGBM] [Info] Number of data points in the train set: 7039, number of used features: 93
# ...

# %%
print("Best parameters found: ", random_search.best_params_)
print("Best accuracy found: ", random_search.best_score_)
# Out:
# Best parameters found:  {'learning_rate': 0.3, 'n_estimators': 131, 'num_leaves': 29}
# Best accuracy found:  0.9899601567680212

# %%
params = {
    'objective': 'binary',
    'metric': 'binary_logloss',
    'boosting': 'gbdt',
    'num_leaves': 40,
    'learning_rate': 0.2,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 5,
    'is_unbalance': True,
    #'scale_pos_weight': 0.75,
    'num_iterations': 100,
    'n_estimators': 150}
train_data = lgb.Dataset(X_resampled, label=y_resampled)
test_data = lgb.Dataset(X_test, label=y_test)
model = lgb.train(params, train_data, valid_sets=[test_data])
X_resampled.shape
y_pred = model.predict(X_test)
print(f'confusion: \n{confusion_matrix(y_test, y_pred.round())}')
print(f"Accuracy: {accuracy_score(y_test, y_pred.round())}")
print(f"Precision: {precision_score(y_test, y_pred.round())}")
print(f"Recall: {recall_score(y_test, y_pred.round())}")
print(f"F1 Score: {f1_score(y_test, y_pred.round())}")

# %%
light gbm i ele
unbalanced <-
scale pos weight ile yoxla 
hyperparameter tuning ele

self note:
ramdom sampling yoxla smote yerine
select k best. best featureleri secmeyi correlationla yoxla
